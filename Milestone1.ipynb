# %%
pip install pandas scikit-learn matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\predator\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\predator\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\predator\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\predator\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\predator\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\predator\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\predator\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\predator\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\predator\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\predator\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\predator\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\predator\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\predator\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\predator\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\predator\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\predator\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\predator\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\predator\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

train_df = pd.read_csv("spam_messages_train.csv")
test_df  = pd.read_csv("spam_messages_test.csv")

train_df.head()
# Out:
#   label                                               text
# 0   ham  Funny fact Nobody teaches volcanoes 2 erupt, t...
# 1   ham  I sent my scores to sophas and i had to do sec...
# 2  spam  We know someone who you know that fancies you....
# 3   ham  Only if you promise your getting out as SOON a...
# 4  spam  Congratulations ur awarded either �500 of CD g...

# %%
x_train_text = train_df["text"]
y_train = train_df["label"]

x_test_text = test_df["text"]
y_test = test_df["label"]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words="english")

x_train = vectorizer.fit_transform(x_train_text)
x_test  = vectorizer.transform(x_test_text)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

model = MultinomialNB()
model.fit(x_train, y_train)

print(classification_report(y_test, model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.94      0.97      0.96      3595
#         spam       0.95      0.91      0.93      2331
#
#     accuracy                           0.95      5926
#    macro avg       0.95      0.94      0.94      5926
# weighted avg       0.95      0.95      0.95      5926

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)

print(classification_report(y_test, model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.95      0.96      0.96      3595
#         spam       0.94      0.93      0.94      2331
#
#     accuracy                           0.95      5926
#    macro avg       0.95      0.95      0.95      5926
# weighted avg       0.95      0.95      0.95      5926

# %%
sample = ["Hello I am Ram. I was you friend back in school"]

sample_vec = vectorizer.transform(sample)
model.predict(sample_vec)
# Out:
# array(['ham'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay(confusion_matrix(y_test, model.predict(x_test))).plot()
plt.show()
